# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier
from sklearn import set_config

set_config(transform_output="pandas")
df=sns.load_dataset('titanic')
df.drop(columns=['adult_male','deck','embark_town','alive','class','who','alone'],inplace=True)
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['survived']),df['survived'],test_size=0.2,random_state=42)

t1=ColumnTransformer([
    ('age_impute',SimpleImputer(),['age']),
    # ('embarked_impute',SimpleImputer(strategy='most_frequent'),['embarked']),
],remainder='passthrough'
)
t2=ColumnTransformer([
    ('ohe',OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore'),['sex','embarked']),
    ('mms',MinMaxScaler(),['age','fare'])
],remainder='passthrough'
)
t4=DecisionTreeClassifier()
pipe=make_pipeline(t1,t4)
pipe.fit(x_train,y_train)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3168\3213787292.py in ?()
#      27 ],remainder='passthrough'
#      28 )
#      29 t4=DecisionTreeClassifier()
#      30 pipe=make_pipeline(t1,t4)
# ---> 31 pipe.fit(x_train,y_train)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\pipeline.py in ?(self, X, y, **params)
#     471         Xt = self._fit(X, y, routed_params)
#     472         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     473             if self._final_estimator != "passthrough":
# ...

# %%
x_train.head()
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked
# 331       1    male  45.5      0      0  28.5000        S
# 733       2    male  23.0      0      0  13.0000        S
# 382       3    male  32.0      0      0   7.9250        S
# 704       3    male  26.0      1      0   7.8542        S
# 813       3  female   6.0      4      2  31.2750        S

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=['survived']),df['survived'],test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked
# 331       1    male  45.5      0      0  28.5000        S
# 733       2    male  23.0      0      0  13.0000        S
# 382       3    male  32.0      0      0   7.9250        S
# 704       3    male  26.0      1      0   7.8542        S
# 813       3  female   6.0      4      2  31.2750        S

# %%
#imputation of missing values
trf1=ColumnTransformer([
    ('age_impute',SimpleImputer(),[2]),
    ('embarked',SimpleImputer(strategy='most_frequent'),[6]),
],remainder='passthrough')

#hendel categorical data
trf2=ColumnTransformer([
    ('sex_embarked_who_alone',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[1,6])
],remainder='passthrough')

#scaling
trf3=ColumnTransformer([
    ('age_fare',MinMaxScaler(),slice(0,10))
])

trf4=DecisionTreeClassifier()

pipe=Pipeline([
    ('trf1',trf1),
    ('trf2',trf2),
    ('trf3',trf3),
    ('trf4',trf4)
])

pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('age_impute', SimpleImputer(),
#                                                   [2]),
#                                                  ('embarked',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6])])),
#                 ('trf2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('sex_embarked_who_alone',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [1, 6])])),
#                 ('trf3',
#                  ColumnTransformer(transformers=[('age_fare', MinMaxScaler(),
# ...
