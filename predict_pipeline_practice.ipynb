# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe=pickle.load(open('trained_models/pipe_practice.pkl','rb'))

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_age', SimpleImputer(),
#                                                   [2]),
#                                                  ('impute_embarked',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6])])),
#                 ('columntransformer-2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_sex_embarked',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [1, 6])])),
#                 ('columntransformer-3',
# ...

# %%
input=np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
x=pipe.predict(input)
# Out:
# C:\Users\zulqa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\zulqa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
if x[0]==0:
    print('not survived')
else:
    print('survived')
# Out:
# not survived
