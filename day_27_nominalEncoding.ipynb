# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# sex1             0
# sex2             0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
si.fit

# %%
pd.get_dummies(df,columns=['sex','embarked'],drop_first=True).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  class    who  adult_male  \
# 0         0       3  22.0      1      0   7.2500  Third    man        True
# 1         1       1  38.0      1      0  71.2833  First  woman       False
# 2         1       3  26.0      0      0   7.9250  Third  woman       False
# 3         1       1  35.0      1      0  53.1000  First  woman       False
# 4         0       3  35.0      0      0   8.0500  Third    man        True
#
#   deck  embark_town alive  alone  sex_male  embarked_Q  embarked_S
# 0  NaN  Southampton    no  False      True       False        True
# 1    C    Cherbourg   yes  False     False       False       False
# 2  NaN  Southampton   yes   True     False       False        True
# 3    C  Southampton   yes  False     False       False        True
# 4  NaN  Southampton    no   True      True       False        True

# %%
x=df['sex']
x=pd.DataFrame(x)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()

# %%
df[['sex1','sex2']]=ohe.fit_transform(x).toarray()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
pd.get_dummies(df,columns=['sex','who'],drop_first=True).head()
# Out:
#    survived  pclass   age  sibsp  parch     fare embarked  class  adult_male  \
# 0         0       3  22.0      1      0   7.2500        S  Third        True
# 1         1       1  38.0      1      0  71.2833        C  First       False
# 2         1       3  26.0      0      0   7.9250        S  Third       False
# 3         1       1  35.0      1      0  53.1000        S  First       False
# 4         0       3  35.0      0      0   8.0500        S  Third        True
#
#   deck  embark_town alive  alone  sex_male  who_man  who_woman
# 0  NaN  Southampton    no  False      True     True      False
# 1    C    Cherbourg   yes  False     False    False       True
# 2  NaN  Southampton   yes   True     False    False       True
# 3    C  Southampton   yes  False     False    False       True
# 4  NaN  Southampton    no   True      True     True      False

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(pd.DataFrame(df['sex']))
# Out:
# OneHotEncoder()

# %%
df[['sexmale','sexfemale']]=ohe.transform(pd.DataFrame(df['sex'])).toarray()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  sexmale  sexfemale
# 0    man        True  NaN  Southampton    no  False      0.0        1.0
# 1  woman       False    C    Cherbourg   yes  False      1.0        0.0
# 2  woman       False  NaN  Southampton   yes   True      1.0        0.0
# 3  woman       False    C  Southampton   yes  False      1.0        0.0
# 4    man        True  NaN  Southampton    no   True      0.0        1.0

# %%
# Out:
# <891x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 891 stored elements in Compressed Sparse Row format>
