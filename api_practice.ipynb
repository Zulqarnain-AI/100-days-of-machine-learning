# %%
for i in range(1,497):
    reponse=requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=9ef357010ff4c52efab8bb16a536ff39&language=en-US&page={i}>')
    a=pd.DataFrame(response.json()['results'])[['id','title','popularity','adult','vote_average','vote_count','original_language','video','release_date']]
    list.append(a)

# %%
import requests
headers = {
    'x-rapidapi-key': "b525d348c4msh20042ad8c71efe0p146546jsn210194ff58f6",
    'x-rapidapi-host': "linkedin-jobs-api2.p.rapidapi.com"
}
    reponse=requests.get("/active-jb-7d?title_filter=%22Data%20Engineer%22&location_filter=%22United%20States%22", headers=headers)
# Out:
#   Cell In[17], line 6
#     reponse=requests.get("/active-jb-7d?title_filter=%22Data%20Engineer%22&location_filter=%22United%20States%22", headers=headers)
#     ^
# IndentationError: unexpected indent

# %%
import http.client

conn = http.client.HTTPSConnection("linkedin-jobs-api2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "b525d348c4msh20042ad8c71efe0p146546jsn210194ff58f6",
    'x-rapidapi-host': "linkedin-jobs-api2.p.rapidapi.com"
}

conn.request("GET", "/active-jb-7d?title_filter=%22Data%20Engineer%22&location_filter=%22United%20States%22", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# b'[{"id":"1336471014","date_posted":"2025-01-27T05:49:18","date_created":"2025-01-27T06:00:40.008004","title":"Optical Network Documentation and Data Engineer, W","organization":"Cogent Communications","organization_url":"https://www.linkedin.com/company/cogent-communications","date_validthrough":"2025-02-26T05:49:18","locations_raw":[{"@type":"Place","address":{"@type":"PostalAddress","addressCountry":"US","addressLocality":"Washington","addressRegion":"DC","streetAddress":null},"latitude":38.892063,"longitude":-77.01991}],"location_type":null,"location_requirements_raw":null,"salary_raw":null,"employment_type":["FULL_TIME"],"url":"https://www.linkedin.com/jobs/view/optical-network-documentation-and-data-engineer-w-at-cogent-communications-4135620621","source_type":"jobboard","source":"linkedin","source_domain":"linkedin.com","organization_logo":"https://media.licdn.com/dms/image/v2/C4D0BAQG-FDlPOmxlbA/company-logo_200_200/company-logo_200_200/0/1631350616023?e=2147483647&amp;v=beta
# ...

# %%
data.decode("utf-8")
# Out:
# '[{"id":"1336300299","date_posted":"2025-01-27T04:37:33","date_created":"2025-01-27T05:00:43.476835","title":"Google Cloud Data Engineer [No-Code/Low-Code]-Senior Manager","organization":"PwC","organization_url":"https://uk.linkedin.com/company/pwc","date_validthrough":"2025-02-26T04:37:33","locations_raw":[{"@type":"Place","address":{"@type":"PostalAddress","addressCountry":"US","addressLocality":"Texas","addressRegion":"United States","streetAddress":null},"latitude":31.463848,"longitude":-99.3333}],"location_type":null,"location_requirements_raw":null,"salary_raw":{"@type":"MonetaryAmount","currency":"USD","value":{"@type":"QuantitativeValue","minValue":130000,"maxValue":256000,"unitText":"YEAR"}},"employment_type":["FULL_TIME"],"url":"https://www.linkedin.com/jobs/view/google-cloud-data-engineer-no-code-low-code-senior-manager-at-pwc-4136089167","source_type":"jobboard","source":"linkedin","source_domain":"linkedin.com","organization_logo":"https://media.licdn.com/dms/image/v2/D4
# ...
